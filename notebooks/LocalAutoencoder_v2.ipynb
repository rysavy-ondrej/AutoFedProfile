# %% [markdown]
# # Install Python libraries
#
# Install the following Python libraries if not already available in the current kernel.

# %%
# !pip install matplotlib
# !pip install tensorflow
# !pip install scikit-learn
# Out:
# Requirement already satisfied: matplotlib in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: tensorflow in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: scikit-learn in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/liuliyu/opt/anaconda3/envs/czech/lib/python3.10/site-packages (from scikit-learn) (3.6.0)

# %% [markdown]
# # Dataset Preparation
#
# The data are read from all samples in the given folder (desktop applications). From the source JSON we extract only the following (numerical) features:
#
# * Flow Data: A subset of columns that contain numerical flow metrics ('BytesOut', 'PacketsOut', 'BytesIn', 'PacketsIn', 'Duration') is extracted from the DataFrame. These values are converted to a NumPy array of type float32.
# * TLS Records size sequence: The 'RecordSequence' column, which holds sequences (arrays) of integers is taken and the array is padded or truncated so that its length is exactly RECORD_SEQUENCE_SIZE (20). These values are converted to a NumPy array of type float32.
#
# The processed numerical flow data and the padded record sequences are concatenated horizontally (column-wise) such that each row has exactly 25 columns. Any NaN values in the concatenated dataset are replaced with 0.
#
# For each column in the dataset, the minimum and maximum values are computed. A min-max normalization is then applied column-wise. This rescales every value so that each feature (column) lies in the range [0,1].
#
# `normal_df` is prepared and can be used for the autoencoder training.

# %%
#
# This is just ot make the visualization nicer...
#
import math

def is_composite(x):
    """Return True if x is composite (not prime) and x >= 4; otherwise False."""
    if x < 4:
        return False  # 2 and 3 are prime; 1 is neither prime nor composite
    for i in range(2, int(math.sqrt(x)) + 1):
        if x % i == 0:
            return True
    return False

def find_nearest_composites(n):
    """Return the composite numbers greater than n."""
    candidates = []
    for i in range(n, int(n * 3 / 2)):
        if is_composite(i):
            candidates.append(i)
    return candidates

def greatest_divisor_pair(x):
    """
    Return the pair of divisors (d, x//d) for composite x such that
    d is the greatest divisor not exceeding sqrt(x). This pair is closest to each other.
    """
    d = int(math.sqrt(x))
    while d > 1:
        if x % d == 0:
            return (d, x // d)
        d -= 1
    return (1, x)

def get_padding_and_dim(x):
    dif = x
    val_x = x
    val_d1 = 0
    val_d2 = 0
    for nearest in find_nearest_composites(x):
        d1, d2 = greatest_divisor_pair(nearest)  
        if (math.fabs(d1-d2) > dif):
            return (val_x, val_d1, val_d2)
        else:
            val_x = nearest
            val_d1 = d1
            val_d2 = d2
            dif = math.fabs(d1-d2)

# %%
import json
import glob
import pandas as pd
import numpy as np
from array import array
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler 
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from collections import Counter

RECORD_SEQUENCE_SIZE=20
tls_columns_names = np.array([f"tls.rec.{i}" for i in range(RECORD_SEQUENCE_SIZE)])

TOP_N_CCS = 20

# Resize row in the array
def resize_row(row, maxlen, pad_value=0):
    current_length = len(row)
    if current_length < maxlen:
        # Calculate the amount of padding needed
        pad_width = maxlen - current_length
        # Pad at the end (you can also pad at the beginning or both sides)
        row = np.pad(row, pad_width=(0, pad_width), mode='constant', constant_values=pad_value)
    else:
        # If the row is longer than the target length, slice it
        row = row[:maxlen]
    return row
# Resize the matrix by padding or removing columns
def pad_sequences(rows, maxlen, pad_value=0):
    resized_rows = [resize_row(row, maxlen) for row in rows]
    return resized_rows

# Loads data from the specified collection of json files. It provides raw data.
def load_json_files(json_files):
    all_data = []
    # Open the file and read each line
    for filename in json_files:
        with open(filename, "r") as file:
            # Use a list comprehension to load each line as a JSON object
            data = [json.loads(line.strip()) for line in file]
            for item in data: all_data.append(item)
    # Convert the list of dictionaries into a DataFrame
    df = pd.DataFrame(all_data)
    return df

def find_top_ccs_values(df, top_n):
    all_ccs = []
    for ccs_list in df['tls.ccs'].dropna():
        if isinstance(ccs_list, list):
            all_ccs.extend(ccs_list)
    
    # Calculate the frequency of each CCS value
    ccs_counter = Counter(all_ccs)
    
    # Get the most common CCS values
    top_ccs = [ccs for ccs, _ in ccs_counter.most_common(top_n)]
    
    print(f"Top {top_n} cipher suites: {top_ccs}")
    return top_ccs

def create_ccs_features(row, top_ccs):
    if not isinstance(row, list):
        return [0] * len(top_ccs)
    
    # Create a binary feature for each cipher suite
    return [1 if ccs in row else 0 for ccs in top_ccs]

# Extracts features from raw dataset. This will provide suitable output to the preprocessing pipeline.
# Flow related columns: 'BytesOut', 'PacketsOut', 'BytesIn', 'PacketsIn', 'Duration'
# TLS handshake columns: 'TlsClientVersion','TlsServerVersion','TlsServerCipherSuite'
# TLS record sizes: 'RecordSequence' mapped as 'TlsRecord_X'
#
# The output is a DataFrame with the above specified columns. This dataframe can beused as the input to next
# processing block (preprocessor).
#
def extract_features(df):
    # cipher suites
    top_ccs = find_top_ccs_values(df, top_n=TOP_N_CCS)
    ccs_column_names = [f'tls.ccs.{ccs}' for ccs in top_ccs]
    ccs_features = df['tls.ccs'].apply(lambda x: create_ccs_features(x, top_ccs))
    ccs_df = pd.DataFrame(ccs_features.tolist(), columns=ccs_column_names)
    
    # Flow data
    flow_data = df[['bs', 'ps', 'br', 'pr', 'td']].astype(float)
    # TLS handshake data
    tls_data = df[['tls.cver','tls.sver','tls.scs']].fillna(0).astype(str) 
    # TLS records 
    records_data = pd.DataFrame( pad_sequences(df['tls.rec'].values, maxlen=RECORD_SEQUENCE_SIZE), columns=tls_columns_names)
    
    dataset = pd.concat([flow_data, tls_data, records_data, ccs_df], axis=1).fillna(0)
    return dataset, top_ccs
#
# Fits the preprocessor that contains scalers for numerical features and OneHotEncoder for categorical data.
# The result is the Pipeline that can be used for further data processing before they are fed in the Autoencoder.
# 
def fit_preprocessor(df, top_ccs):
    # Define cipher suite columns
    ccs_column_names = [f'tls.ccs.{ccs}' for ccs in top_ccs]
    
    preprocessor = ColumnTransformer(
        transformers=[
            ('num_flow', MinMaxScaler(), ['bs', 'ps', 'br', 'pr', 'td']),
            ('num_tls', MinMaxScaler(), tls_columns_names),
            ('num_ccs', MinMaxScaler(), ccs_column_names), 
            ('cat', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), ['tls.cver','tls.sver','tls.scs'])
        ])
    pipeline = Pipeline(steps=[('preprocessor', preprocessor)])
    pipeline.fit(df)
    return pipeline

# -------------------------------------------------
# Load normal data and prepare them for Autoencoder
# Normal data are for now represented as the desktop application communication.
#
raw_df = load_json_files(glob.glob("../datasets/desktop.tls/*.json"))
print(f'dataset shape={raw_df.shape}')
input_df, top_ccs = extract_features(raw_df)

global_top_ccs = top_ccs

pipeline = fit_preprocessor(input_df, top_ccs)
normal_df = pipeline.transform(input_df)

print('Normalized row of data:')
print(normal_df[0])

print(f'dataset shape={normal_df.shape}')

row_len = normal_df.shape[1]
(newrow_len,IMAGE_DIM_X,IMAGE_DIM_Y) = get_padding_and_dim(row_len)
IMAGE_PAD= newrow_len - row_len
print(f"visualization adjustement: {row_len} -> {newrow_len} (+ {IMAGE_PAD}) [{IMAGE_DIM_X} x {IMAGE_DIM_Y}]")

def make_image_from_sample(sample):
    return np.pad(sample, pad_width=(0,IMAGE_PAD), mode='constant', constant_values=0).reshape(IMAGE_DIM_X, IMAGE_DIM_Y)
# Out:
# dataset shape=(14962, 28)
# Top 20 cipher suites: ['C02B', 'C02F', 'C02C', 'C030', 'C013', 'C014', '009C', '009D', '002F', '0035', 'CCA9', 'CCA8', '1301', '1302', '1303', 'C00A', 'C009', 'C027', '000A', 'C024']
# Normalized row of data:
# [2.17753132e-03 2.21631206e-03 9.79934060e-05 8.92359175e-04
#  6.24198375e-03 8.35066163e-01 9.25056978e-03 1.61063331e-02
#  4.89771620e-01 9.18864858e-02 4.91283677e-02 1.96893508e-01
#  5.67007398e-02 3.53978244e-01 2.29417032e-01 3.23067383e-01
#  3.14913671e-01 2.98925203e-01 2.89292228e-01 5.08128222e-01
#  5.07518224e-01 5.00594748e-01 4.98520755e-01 4.99557752e-01
#  4.99557752e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00]
# dataset shape=(14962, 55)
# visualization adjustement: 55 -> 56 (+ 1) [7 x 8]

# %% [markdown]
# # Autoencoder Training
#
# The autoencoder is trained on `normal_df`. The data are split into training (80%) and testing (20%) parts. The size of laten space is set to `LATENT_SPACE_SIZE`.
#
# The results are visualzied for the 10 selected sample.
#
# Read more: https://www.tensorflow.org/tutorials/generative/autoencoder

# %%
import os
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
LATENT_SPACE_SIZE=6

# 1. Split data to traingin and testing
# x_train, x_test = train_test_split(normal_df, test_size=0.2)
# print(f'train shape={x_train.shape}')
# print(f'test shape={x_test.shape}')
x_train, x_test = train_test_split(normal_df, test_size=0.2, random_state=42)
print(f'train dataset={x_train.shape}')
print(f'test dataset(normal)={x_test.shape}')

# 2. Define dimensions and architecture
input_dim = x_train.shape[1]
encoding_dim = LATENT_SPACE_SIZE  # Size of the latent space

# Input placeholder
input_img = Input(shape=(input_dim,))

# Encoder layers
encoded = Dense(encoding_dim, activation='relu')(input_img)

# Decoder layers
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Encoder model for later use
encoder = Model(input_img, encoded)

# Decoder model setup
encoded_input = Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer(encoded_input))

# 3. Compile and train the autoencoder
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(x_train, x_train,
                epochs=50,                      # use some more reasonable number here (>50)
                batch_size=16,
                shuffle=True,
                validation_data=(x_test, x_test))

# 4. Visualize the reconstructed images
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# Assuming x_test contains the original test data
# and decoded_imgs are the autoencoder's reconstructed outputs
reconstruction_errors = np.mean(np.square(x_test - decoded_imgs), axis=1)

# Average reconstruction error across all samples
avg_error = np.mean(reconstruction_errors)
max_error = np.max(reconstruction_errors)
min_error = np.min(reconstruction_errors)
print(f"Reconstruction error for each sample {reconstruction_errors}")
print(f"Average={avg_error}, Max={max_error}, Min={min_error} reconstruction errors.")

# Get indices that would sort the array in ascending order
worst20 = np.argsort(reconstruction_errors)[-20:][::-1]

n = 20  # Number of digits to display
i = 0

print("Worst reconstructed:")
plt.figure(figsize=(20, 4))
for j in worst20:
    reconstruction_error = reconstruction_errors[j]
    original = x_test[j]
    original = make_image_from_sample(original) 
    reconstructed = decoded_imgs[j]
    reconstructed = make_image_from_sample(reconstructed) 
    # Original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(original, cmap='gray')
    plt.title("Original")
    plt.axis('off')
    
    # Reconstructed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(reconstructed, cmap='gray')
    plt.title(f"RE {reconstruction_error:.3f}")
    plt.axis('off')
    i+=1
plt.show()
# Out:
# train dataset=(11969, 55)
# test dataset(normal)=(2993, 55)
# Epoch 1/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - loss: 0.4308 - val_loss: 0.2587
# Epoch 2/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.2536 - val_loss: 0.2416
# Epoch 3/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 649us/step - loss: 0.2379 - val_loss: 0.2279
# Epoch 4/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 656us/step - loss: 0.2252 - val_loss: 0.2195
# Epoch 5/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 0.2177 - val_loss: 0.2138
# Epoch 6/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 0.2127 - val_loss: 0.2101
# Epoch 7/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 651us/step - loss: 0.2087 - val_loss: 0.2076
# Epoch 8/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.2069 - val_loss: 0.2058
# Epoch 9/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step - loss: 0.2051 - val_loss: 0.2045
# Epoch 10/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 653us/step - loss: 0.2039 - val_loss: 0.2035
# Epoch 11/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 0.2027 - val_loss: 0.2027
# Epoch 12/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - loss: 0.2019 - val_loss: 0.2021
# Epoch 13/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.2014 - val_loss: 0.2017
# Epoch 14/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 0.2014 - val_loss: 0.2014
# Epoch 15/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.2006 - val_loss: 0.2009
# Epoch 16/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.2000 - val_loss: 0.2006
# Epoch 17/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.1997 - val_loss: 0.2002
# Epoch 18/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step - loss: 0.1998 - val_loss: 0.2000
# Epoch 19/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 654us/step - loss: 0.1991 - val_loss: 0.1997
# Epoch 20/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 661us/step - loss: 0.1991 - val_loss: 0.1996
# Epoch 21/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step - loss: 0.1987 - val_loss: 0.1992
# Epoch 22/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 965us/step - loss: 0.1986 - val_loss: 0.1989
# Epoch 23/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 744us/step - loss: 0.1983 - val_loss: 0.1987
# Epoch 24/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - loss: 0.1983 - val_loss: 0.1986
# Epoch 25/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 670us/step - loss: 0.1981 - val_loss: 0.1985
# Epoch 26/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step - loss: 0.1978 - val_loss: 0.1983
# Epoch 27/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step - loss: 0.1980 - val_loss: 0.1980
# Epoch 28/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 737us/step - loss: 0.1977 - val_loss: 0.1979
# Epoch 29/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 662us/step - loss: 0.1974 - val_loss: 0.1977
# Epoch 30/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - loss: 0.1972 - val_loss: 0.1976
# Epoch 31/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 652us/step - loss: 0.1970 - val_loss: 0.1975
# Epoch 32/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 657us/step - loss: 0.1970 - val_loss: 0.1973
# Epoch 33/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - loss: 0.1968 - val_loss: 0.1973
# Epoch 34/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step - loss: 0.1968 - val_loss: 0.1972
# Epoch 35/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - loss: 0.1966 - val_loss: 0.1970
# Epoch 36/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 743us/step - loss: 0.1968 - val_loss: 0.1969
# Epoch 37/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 668us/step - loss: 0.1963 - val_loss: 0.1968
# Epoch 38/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step - loss: 0.1965 - val_loss: 0.1967
# Epoch 39/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step - loss: 0.1962 - val_loss: 0.1966
# Epoch 40/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 662us/step - loss: 0.1961 - val_loss: 0.1965
# Epoch 41/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 664us/step - loss: 0.1962 - val_loss: 0.1965
# Epoch 42/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 656us/step - loss: 0.1958 - val_loss: 0.1964
# Epoch 43/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.1958 - val_loss: 0.1963
# Epoch 44/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 0.1958 - val_loss: 0.1963
# Epoch 45/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 668us/step - loss: 0.1956 - val_loss: 0.1963
# Epoch 46/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - loss: 0.1959 - val_loss: 0.1961
# Epoch 47/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 1s 650us/step - loss: 0.1957 - val_loss: 0.1961
# Epoch 48/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.1956 - val_loss: 0.1961
# Epoch 49/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - loss: 0.1957 - val_loss: 0.1960
# Epoch 50/50
# 749/749 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - loss: 0.1955 - val_loss: 0.1959
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step
# Reconstruction error for each sample [0.00067786 0.00431665 0.00021227 ... 0.00040981 0.00090777 0.00370599]
# Average=0.002593724289075165, Max=0.06910151423717388, Min=0.00013656545462432574 reconstruction errors.
# Worst reconstructed:

# %% [markdown]
# # Test with unknown data
#
# Next, we load ISCX data set and use previously trained Autoencoder. The reconstruction error shuld be significantly higher.

# %%
# Function to extract features ensuring all columns match what the pipeline expects 
def extract_features_for_pipeline(df, global_top_ccs):
    """
    Extract features ensuring compatibility with the pipeline by using the global top CCS list.
    
    Parameters:
    -----------
    df : DataFrame
        The raw dataframe with TLS records
    global_top_ccs : list
        List of top CCS values used during training
    
    Returns:
    --------
    DataFrame
        Processed dataframe with extracted features
    """
    # For each global CCS value, create a binary feature column
    ccs_column_names = [f'tls.ccs.{ccs}' for ccs in global_top_ccs]
    
    # Generate CCS features based on the global list to ensure column alignment
    ccs_features = df['tls.ccs'].apply(lambda x: create_ccs_features(x, global_top_ccs))
    ccs_df = pd.DataFrame(ccs_features.tolist(), columns=ccs_column_names)
    
    # Flow data
    flow_data = df[['bs', 'ps', 'br', 'pr', 'td']].astype(float)
    # TLS handshake data
    tls_data = df[['tls.cver','tls.sver','tls.scs']].fillna(0).astype(str) 
    # TLS records 
    records_data = pd.DataFrame(pad_sequences(df['tls.rec'].values, maxlen=RECORD_SEQUENCE_SIZE), columns=tls_columns_names)
    
    # Combine all features
    dataset = pd.concat([flow_data, tls_data, ccs_df, records_data], axis=1).fillna(0)
    return dataset

# This function should be called right after defining the global top CCS values
# in your main training code, before the test code
def initialize_global_top_ccs(top_ccs):
    """
    Initialize the global_top_ccs variable to be used across all dataset testing.
    
    Parameters:
    -----------
    top_ccs : list
        List of top CCS values used during training
    """
    global global_top_ccs
    global_top_ccs = top_ccs
    print(f"Initialized global top CCS list with {len(global_top_ccs)} values")

# %%
def test_dataset(json_files, top_ccs, dataset_name="Unnamed Dataset", export_results=False, results_file="tls_test_results.xlsx"):
    """
    Test a TLS dataset and print detailed results in English.
    
    Parameters:
    -----------
    json_files : list or glob pattern
        The JSON files containing TLS records to test
    top_ccs : list
        List of top CCS values used during training
    dataset_name : str
        Name of the dataset being tested (for reporting)
    export_results : bool
        Whether to export results to Excel file
    results_file : str
        Path to Excel file for exporting results
    """
    import pandas as pd
    import time
    from datetime import datetime

    # Start timing
    start_time = time.time()
    
    # Load and process data
    raw_test_df = load_json_files(json_files)
    
    # Find this dataset's own top CCS values (for analysis purposes)
    dataset_top_ccs = find_top_ccs_values(raw_test_df, top_n=TOP_N_CCS)
    print(f"Top 30 cipher suites in {dataset_name}: {dataset_top_ccs}")
    
    # Compare with training dataset's CCS values
    common_ccs = set(dataset_top_ccs) & set(top_ccs)
    unique_ccs = set(dataset_top_ccs) - set(top_ccs)
    print(f"CCS values in common with training data: {len(common_ccs)}")
    print(f"CCS values unique to this dataset: {len(unique_ccs)}")
    if unique_ccs:
        print(f"Unique CCS values: {', '.join(list(unique_ccs)[:10])}")
    
    # Use training top CCS for feature extraction to ensure model compatibility
    input_test_df = extract_features_for_pipeline(raw_test_df, top_ccs)
    
    # Transform data using the pipeline
    test_df = pipeline.transform(input_test_df)
    print(f"Processed dataset shape: {test_df.shape} ({test_df.shape[0]} samples with {test_df.shape[1]} features)")
    
    # Encode and decode using the autoencoder
    encoded_test = encoder.predict(test_df)
    decoded_test = decoder.predict(encoded_test)
    
    # Calculate reconstruction errors
    test_reconstruction_errors = np.mean(np.square(test_df - decoded_test), axis=1)
    
    # Calculate statistics
    test_avg_error = np.mean(test_reconstruction_errors)
    test_median_error = np.median(test_reconstruction_errors)
    test_std_error = np.std(test_reconstruction_errors)
    test_min_error = np.min(test_reconstruction_errors)
    test_max_error = np.max(test_reconstruction_errors)
    
    # Get percentiles for better distribution understanding
    percentiles = [25, 50, 75, 90, 95, 99]
    error_percentiles = np.percentile(test_reconstruction_errors, percentiles)
    
    # Get best and worst samples
    best10 = np.argsort(test_reconstruction_errors)[:10]
    worst10 = np.argsort(test_reconstruction_errors)[-10:][::-1]
    
    # Calculate elapsed time
    elapsed_time = time.time() - start_time
    
    # Print comprehensive results
    print("\nRECONSTRUCTION ERROR ANALYSIS:")
    print(f"Average reconstruction error: {test_avg_error:.6f}")
    print(f"Median reconstruction error:  {test_median_error:.6f}")
    print(f"Std deviation of errors:      {test_std_error:.6f}")
    print(f"Min reconstruction error:     {test_min_error:.6f}")
    print(f"Max reconstruction error:     {test_max_error:.6f}")
    
    print("\nERROR DISTRIBUTION (PERCENTILES):")
    for p, val in zip(percentiles, error_percentiles):
        print(f"{p}th percentile: {val:.6f}")
    
    # Print information about worst samples
    print("\nWORST RECONSTRUCTED SAMPLES:")
    for i, idx in enumerate(worst10):
        print(f"Sample {idx}: Reconstruction Error = {test_reconstruction_errors[idx]:.6f}")
    
    # Print information about best samples
    print("\nBEST RECONSTRUCTED SAMPLES:")
    for i, idx in enumerate(best10):
        print(f"Sample {idx}: Reconstruction Error = {test_reconstruction_errors[idx]:.6f}")
    
    # Visualize results
    n = 10  # Number of samples to display
    plt.figure(figsize=(20, 4))
    for i, j in enumerate(worst10):
        rec_error = test_reconstruction_errors[j]
        original = test_df[j]
        original = make_image_from_sample(original)  
        reconstructed = decoded_test[j]
        reconstructed = make_image_from_sample(reconstructed)
        
        # Original images
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(original, cmap='gray')
        plt.title("Original")
        plt.axis('off')
        
        # Reconstructed images
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(reconstructed, cmap='gray')
        plt.title(f"RE {rec_error:.3f}")
        plt.axis('off')
    
    plt.suptitle(f"Worst Reconstructed Samples - {dataset_name}", fontsize=16)
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    # plt.savefig(f"{dataset_name.replace(' ', '_')}_worst_samples.png")
    plt.show()
    
    # Performance summary
    print("\nPERFORMANCE SUMMARY:")
    print(f"Dataset: {dataset_name}")
    print(f"Number of samples: {raw_test_df.shape[0]}")
    print(f"Number of features: {test_df.shape[1]}")
    print(f"Average reconstruction error: {test_avg_error:.6f}")
    print(f"Processing time: {elapsed_time:.2f} seconds")
    
    # Export results if requested
    if export_results:
        # Prepare results dictionary
        results_dict = {
            'Dataset Name': dataset_name,
            'Timestamp': datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            'Number of Samples': raw_test_df.shape[0],
            'Number of Features': test_df.shape[1],
            'Average Error': test_avg_error,
            'Median Error': test_median_error,
            'Std Deviation': test_std_error,
            'Min Error': test_min_error,
            'Max Error': test_max_error,
            'Processing Time (s)': elapsed_time
        }
        
        # Add percentiles
        for p, val in zip(percentiles, error_percentiles):
            results_dict[f'Percentile {p}'] = val
        
        # Create DataFrame
        results_df = pd.DataFrame([results_dict])
        
        try:
            # Check if file exists
            if os.path.exists(results_file):
                existing_results = pd.read_excel(results_file)
                updated_results = pd.concat([existing_results, results_df], ignore_index=True)
            else:
                updated_results = results_df
                
            # Save to Excel
            updated_results.to_excel(results_file, index=False)
            print(f"\nResults successfully exported to {results_file}")
            
        except Exception as e:
            pass
            # print(f"\nError exporting results: {e}")
            # Create backup CSV
            # backup_file = f"backup_results_{datetime.now().strftime('%Y%m%d%H%M%S')}.csv"
            # results_df.to_csv(backup_file, index=False)
            # print(f"Created backup CSV: {backup_file}")
    
    return {
        'dataset_name': dataset_name,
        'avg_error': test_avg_error,
        'median_error': test_median_error,
        'std_error': test_std_error,
        'min_error': test_min_error,
        'max_error': test_max_error,
        'raw_shape': raw_test_df.shape,
        'processed_shape': test_df.shape,
        'errors': test_reconstruction_errors,
        'top_ccs': dataset_top_ccs  # Include dataset's own top CCS values in the results
    }

# %%
results = {}

raw_df = load_json_files(glob.glob("../datasets/desktop.tls/*.json"))
input_df, top_ccs = extract_features(raw_df)

# Test ISCX dataset
results['iscx'] = test_dataset(
    json_files=glob.glob("../datasets/iscx.tls/*.json"),
    top_ccs=top_ccs,
    dataset_name="ISCX TLS Dataset",
    export_results=True
)

# Test Mobile dataset
results['mobile'] = test_dataset(
    glob.glob("../datasets/mobile.tls/*.json"),
    top_ccs=top_ccs,
    dataset_name="Mobile TLS Dataset",
    export_results=True
)

results['windows'] = test_dataset(
    glob.glob("../datasets/windows.tls/*.json"),
    top_ccs=top_ccs,
    dataset_name="windows TLS Dataset",
    export_results=True
)

results['cic-aa.normal'] = test_dataset(
    glob.glob("../datasets/cic-aa.normal.tls/*.json"),
    top_ccs=top_ccs,
    dataset_name="cic-aa.normal TLS Dataset",
    export_results=True
)

results['cic-aa.malware'] = test_dataset(
    glob.glob("../datasets/cic-aa.malware.tls/*.json"),
    top_ccs=top_ccs,
    dataset_name="cic-aa.malware TLS Dataset",
    export_results=True
)

results['cic-aa.adware'] = test_dataset(
    glob.glob("../datasets/cic-aa.adware.tls/*.json"),
    top_ccs=top_ccs,
    dataset_name="cic-aa.adware TLS Dataset",
    export_results=True
)

# Compare datasets
print("\n" + "="*80)
print("COMPARISON OF DATASETS")
print("="*80)

comparison_data = []
for name, result in results.items():
    comparison_data.append({
        'Dataset': result['dataset_name'],
        'Samples': result['raw_shape'][0],
        'Features': result['processed_shape'][1],
        'Avg Error': result['avg_error'],
        'Max Error': result['max_error'],
        'Min Error': result['min_error']
    })

comparison_df = pd.DataFrame(comparison_data)
print(comparison_df.to_string(index=False))

# Optional: Analysis of CCS differences between datasets
print("\n" + "="*80)
print("CCS USAGE COMPARISON BETWEEN DATASETS")
print("="*80)

# Skip normal_test as it doesn't have top_ccs
dataset_ccs = {name: result.get('top_ccs', []) for name, result in results.items() if 'top_ccs' in result}

# Find common and unique CCS across datasets
all_ccs = set()
for ccs_list in dataset_ccs.values():
    all_ccs.update(ccs_list)

print(f"Total unique CCS values across all datasets: {len(all_ccs)}")

# Count how many datasets each CCS appears in
ccs_dataset_count = {ccs: sum(1 for ccs_list in dataset_ccs.values() if ccs in ccs_list) for ccs in all_ccs}

# Find common CCS (in all datasets)
common_ccs = [ccs for ccs, count in ccs_dataset_count.items() if count == len(dataset_ccs)]
print(f"CCS values common to all datasets: {len(common_ccs)}")
if common_ccs:
    print(f"Common CCS: {', '.join(common_ccs)}")

# Find unique CCS (in only one dataset)
for name, ccs_list in dataset_ccs.items():
    unique_to_dataset = [ccs for ccs in ccs_list if ccs_dataset_count[ccs] == 1]
    if unique_to_dataset:
        print(f"\nCCS values unique to {name}: {len(unique_to_dataset)}")
        print(f"Unique CCS: {', '.join(unique_to_dataset[:10])}{'...' if len(unique_to_dataset) > 10 else ''}")
# Out:
# Top 20 cipher suites: ['C02B', 'C02F', 'C02C', 'C030', 'C013', 'C014', '009C', '009D', '002F', '0035', 'CCA9', 'CCA8', '1301', '1302', '1303', 'C00A', 'C009', 'C027', '000A', 'C024']
# Top 20 cipher suites: ['002F', '0035', '000A', 'C00A', 'C009', 'C013', 'C014', 'C02B', '0005', '0004', '0033', '0039', '0032', 'C02F', 'C007', 'C011', '0038', '0045', '0088', '0016']
# Top 30 cipher suites in ISCX TLS Dataset: ['002F', '0035', '000A', 'C00A', 'C009', 'C013', 'C014', 'C02B', '0005', '0004', '0033', '0039', '0032', 'C02F', 'C007', 'C011', '0038', '0045', '0088', '0016']
# CCS values in common with training data: 9
# CCS values unique to this dataset: 11
# Unique CCS values: 0004, 0038, 0032, C007, C011, 0033, 0005, 0045, 0016, 0088
# Processed dataset shape: (1112, 55) (1112 samples with 55 features)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
#
# RECONSTRUCTION ERROR ANALYSIS:
# Average reconstruction error: 0.299218
# Median reconstruction error:  0.131665
# Std deviation of errors:      1.009473
# Min reconstruction error:     0.001216
# Max reconstruction error:     21.096177
#
# ERROR DISTRIBUTION (PERCENTILES):
# 25th percentile: 0.106871
# 50th percentile: 0.131665
# 75th percentile: 0.196539
# 90th percentile: 0.523679
# 95th percentile: 0.830460
# 99th percentile: 4.806877
#
# WORST RECONSTRUCTED SAMPLES:
# Sample 316: Reconstruction Error = 21.096177
# Sample 105: Reconstruction Error = 10.688709
# Sample 92: Reconstruction Error = 10.665341
# Sample 1090: Reconstruction Error = 9.630133
# Sample 1089: Reconstruction Error = 9.013398
# Sample 162: Reconstruction Error = 7.791840
# Sample 124: Reconstruction Error = 7.522355
# Sample 857: Reconstruction Error = 5.636413
# Sample 184: Reconstruction Error = 5.124524
# Sample 493: Reconstruction Error = 4.989275
#
# BEST RECONSTRUCTED SAMPLES:
# Sample 198: Reconstruction Error = 0.001216
# Sample 817: Reconstruction Error = 0.001220
# Sample 1104: Reconstruction Error = 0.001359
# Sample 781: Reconstruction Error = 0.001359
# Sample 815: Reconstruction Error = 0.001437
# Sample 195: Reconstruction Error = 0.001438
# Sample 476: Reconstruction Error = 0.001438
# Sample 117: Reconstruction Error = 0.001441
# Sample 194: Reconstruction Error = 0.001442
# Sample 686: Reconstruction Error = 0.001442
# PERFORMANCE SUMMARY:
# Dataset: ISCX TLS Dataset
# Number of samples: 1112
# Number of features: 55
# Average reconstruction error: 0.299218
# Processing time: 0.19 seconds
# Top 20 cipher suites: ['C02B', 'C02F', 'C02C', 'C030', 'CCA9', 'CCA8', '1301', '1302', '1303', 'C013', 'C014', '009C', '002F', '0035', '009D', 'C009', 'C00A', '000A', 'C008', 'C012']
# Top 30 cipher suites in Mobile TLS Dataset: ['C02B', 'C02F', 'C02C', 'C030', 'CCA9', 'CCA8', '1301', '1302', '1303', 'C013', 'C014', '009C', '002F', '0035', '009D', 'C009', 'C00A', '000A', 'C008', 'C012']
# CCS values in common with training data: 18
# CCS values unique to this dataset: 2
# Unique CCS values: C012, C008
# Processed dataset shape: (5616, 55) (5616 samples with 55 features)
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# RECONSTRUCTION ERROR ANALYSIS:
# Average reconstruction error: 0.022847
# Median reconstruction error:  0.001950
# Std deviation of errors:      0.047159
# Min reconstruction error:     0.000199
# Max reconstruction error:     0.267810
#
# ERROR DISTRIBUTION (PERCENTILES):
# 25th percentile: 0.000857
# 50th percentile: 0.001950
# 75th percentile: 0.033397
# 90th percentile: 0.057873
# 95th percentile: 0.127689
# 99th percentile: 0.226720
#
# WORST RECONSTRUCTED SAMPLES:
# Sample 1858: Reconstruction Error = 0.267810
# Sample 430: Reconstruction Error = 0.266657
# Sample 3515: Reconstruction Error = 0.265941
# Sample 4368: Reconstruction Error = 0.265225
# Sample 2045: Reconstruction Error = 0.260662
# Sample 1889: Reconstruction Error = 0.260480
# Sample 3797: Reconstruction Error = 0.257586
# Sample 4364: Reconstruction Error = 0.255997
# Sample 5349: Reconstruction Error = 0.255773
# Sample 5363: Reconstruction Error = 0.255600
#
# BEST RECONSTRUCTED SAMPLES:
# Sample 277: Reconstruction Error = 0.000199
# Sample 5525: Reconstruction Error = 0.000215
# Sample 3269: Reconstruction Error = 0.000238
# Sample 5336: Reconstruction Error = 0.000239
# Sample 5482: Reconstruction Error = 0.000243
# Sample 1146: Reconstruction Error = 0.000263
# Sample 2901: Reconstruction Error = 0.000264
# Sample 1147: Reconstruction Error = 0.000267
# Sample 3858: Reconstruction Error = 0.000267
# Sample 3418: Reconstruction Error = 0.000268
# PERFORMANCE SUMMARY:
# Dataset: Mobile TLS Dataset
# Number of samples: 5616
# Number of features: 55
# Average reconstruction error: 0.022847
# Processing time: 0.85 seconds
# Top 20 cipher suites: ['C02C', 'C02B', 'C030', 'C02F', 'C013', 'C014', '009C', '009D', '002F', '0035', 'CCA9', 'CCA8', '1302', '1301', '1303', 'C00A', 'C009', 'C027', '000A', 'C024']
# Top 30 cipher suites in windows TLS Dataset: ['C02C', 'C02B', 'C030', 'C02F', 'C013', 'C014', '009C', '009D', '002F', '0035', 'CCA9', 'CCA8', '1302', '1301', '1303', 'C00A', 'C009', 'C027', '000A', 'C024']
# CCS values in common with training data: 20
# CCS values unique to this dataset: 0
# Processed dataset shape: (15047, 55) (15047 samples with 55 features)
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step
# 471/471 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step
#
# RECONSTRUCTION ERROR ANALYSIS:
# Average reconstruction error: 0.002656
# Median reconstruction error:  0.001019
# Std deviation of errors:      0.006146
# Min reconstruction error:     0.000134
# Max reconstruction error:     0.160804
#
# ERROR DISTRIBUTION (PERCENTILES):
# 25th percentile: 0.000474
# 50th percentile: 0.001019
# 75th percentile: 0.002566
# 90th percentile: 0.006439
# 95th percentile: 0.009799
# 99th percentile: 0.021209
#
# WORST RECONSTRUCTED SAMPLES:
# Sample 5843: Reconstruction Error = 0.160804
# Sample 10957: Reconstruction Error = 0.153228
# Sample 14930: Reconstruction Error = 0.141547
# Sample 14957: Reconstruction Error = 0.141310
# Sample 14964: Reconstruction Error = 0.140429
# Sample 14945: Reconstruction Error = 0.140145
# Sample 14960: Reconstruction Error = 0.140145
# Sample 5753: Reconstruction Error = 0.126335
# Sample 5649: Reconstruction Error = 0.091413
# Sample 12061: Reconstruction Error = 0.069102
#
# BEST RECONSTRUCTED SAMPLES:
# Sample 7826: Reconstruction Error = 0.000134
# Sample 2104: Reconstruction Error = 0.000134
# Sample 7906: Reconstruction Error = 0.000134
# Sample 2277: Reconstruction Error = 0.000135
# Sample 2523: Reconstruction Error = 0.000135
# Sample 2474: Reconstruction Error = 0.000135
# Sample 2557: Reconstruction Error = 0.000136
# Sample 8024: Reconstruction Error = 0.000137
# Sample 8516: Reconstruction Error = 0.000137
# Sample 8830: Reconstruction Error = 0.000137
# PERFORMANCE SUMMARY:
# Dataset: windows TLS Dataset
# Number of samples: 15047
# Number of features: 55
# Average reconstruction error: 0.002656
# Processing time: 1.84 seconds
# Top 20 cipher suites: ['002F', '0035', 'C013', 'C014', 'C009', 'C00A', 'C02F', 'C02B', '009C', 'C030', 'C02C', '009D', '0033', '00FF', '0039', '009E', '0005', 'C011', 'C007', '009F']
# Top 30 cipher suites in cic-aa.normal TLS Dataset: ['002F', '0035', 'C013', 'C014', 'C009', 'C00A', 'C02F', 'C02B', '009C', 'C030', 'C02C', '009D', '0033', '00FF', '0039', '009E', '0005', 'C011', 'C007', '009F']
# CCS values in common with training data: 12
# CCS values unique to this dataset: 8
# Unique CCS values: C011, C007, 0033, 0005, 009E, 009F, 00FF, 0039
# Processed dataset shape: (31179, 55) (31179 samples with 55 features)
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step
#
# RECONSTRUCTION ERROR ANALYSIS:
# Average reconstruction error: 448.125089
# Median reconstruction error:  0.163580
# Std deviation of errors:      12806.385899
# Min reconstruction error:     0.000838
# Max reconstruction error:     734905.139480
#
# ERROR DISTRIBUTION (PERCENTILES):
# 25th percentile: 0.079722
# 50th percentile: 0.163580
# 75th percentile: 0.956770
# 90th percentile: 1.232075
# 95th percentile: 1.361640
# 99th percentile: 66.970072
#
# WORST RECONSTRUCTED SAMPLES:
# Sample 21451: Reconstruction Error = 734905.139480
# Sample 23765: Reconstruction Error = 708424.077078
# Sample 19068: Reconstruction Error = 682236.658447
# Sample 25326: Reconstruction Error = 661230.163733
# Sample 20481: Reconstruction Error = 606460.249022
# Sample 24187: Reconstruction Error = 581716.773465
# Sample 23283: Reconstruction Error = 546005.349729
# Sample 23914: Reconstruction Error = 538975.446338
# Sample 24823: Reconstruction Error = 533787.199467
# Sample 24712: Reconstruction Error = 423477.308865
#
# BEST RECONSTRUCTED SAMPLES:
# Sample 8399: Reconstruction Error = 0.000838
# Sample 7735: Reconstruction Error = 0.001697
# Sample 25643: Reconstruction Error = 0.001707
# Sample 25964: Reconstruction Error = 0.001987
# Sample 25962: Reconstruction Error = 0.002013
# Sample 26099: Reconstruction Error = 0.002021
# Sample 26011: Reconstruction Error = 0.002025
# Sample 25922: Reconstruction Error = 0.002034
# Sample 25589: Reconstruction Error = 0.002034
# Sample 26110: Reconstruction Error = 0.002036
# PERFORMANCE SUMMARY:
# Dataset: cic-aa.normal TLS Dataset
# Number of samples: 31179
# Number of features: 55
# Average reconstruction error: 448.125089
# Processing time: 3.87 seconds
# Top 20 cipher suites: ['002F', '0035', 'C009', 'C00A', 'C013', 'C014', 'C02B', 'C02F', '009C', '0033', '0039', '009E', '00FF', '0005', 'C007', 'C011', 'C02C', 'C030', '009D', '009F']
# Top 30 cipher suites in cic-aa.malware TLS Dataset: ['002F', '0035', 'C009', 'C00A', 'C013', 'C014', 'C02B', 'C02F', '009C', '0033', '0039', '009E', '00FF', '0005', 'C007', 'C011', 'C02C', 'C030', '009D', '009F']
# CCS values in common with training data: 12
# CCS values unique to this dataset: 8
# Unique CCS values: C011, C007, 0033, 0005, 009E, 009F, 00FF, 0039
# Processed dataset shape: (462, 55) (462 samples with 55 features)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# RECONSTRUCTION ERROR ANALYSIS:
# Average reconstruction error: 0.360867
# Median reconstruction error:  0.096530
# Std deviation of errors:      1.460402
# Min reconstruction error:     0.031746
# Max reconstruction error:     23.866078
#
# ERROR DISTRIBUTION (PERCENTILES):
# 25th percentile: 0.056814
# 50th percentile: 0.096530
# 75th percentile: 0.201961
# 90th percentile: 0.901162
# 95th percentile: 1.231450
# 99th percentile: 2.402412
#
# WORST RECONSTRUCTED SAMPLES:
# Sample 46: Reconstruction Error = 23.866078
# Sample 80: Reconstruction Error = 18.579263
# Sample 380: Reconstruction Error = 4.051288
# Sample 439: Reconstruction Error = 3.273627
# Sample 287: Reconstruction Error = 2.430226
# Sample 402: Reconstruction Error = 2.384628
# Sample 285: Reconstruction Error = 2.169304
# Sample 249: Reconstruction Error = 2.052924
# Sample 73: Reconstruction Error = 1.580207
# Sample 41: Reconstruction Error = 1.560562
#
# BEST RECONSTRUCTED SAMPLES:
# Sample 338: Reconstruction Error = 0.031746
# Sample 254: Reconstruction Error = 0.031752
# Sample 201: Reconstruction Error = 0.031764
# Sample 315: Reconstruction Error = 0.031897
# Sample 192: Reconstruction Error = 0.031967
# Sample 122: Reconstruction Error = 0.031986
# Sample 352: Reconstruction Error = 0.031998
# Sample 347: Reconstruction Error = 0.032060
# Sample 317: Reconstruction Error = 0.032087
# Sample 366: Reconstruction Error = 0.032087
# PERFORMANCE SUMMARY:
# Dataset: cic-aa.malware TLS Dataset
# Number of samples: 462
# Number of features: 55
# Average reconstruction error: 0.360867
# Processing time: 0.14 seconds
# Top 20 cipher suites: ['C02B', 'C02F', '009E', 'C009', 'C00A', 'C013', 'C014', '0033', '0039', '009C', '002F', '0035', '00FF', 'C007', 'C011', '0005', 'C02C', 'C030', '009F', '009D']
# Top 30 cipher suites in cic-aa.adware TLS Dataset: ['C02B', 'C02F', '009E', 'C009', 'C00A', 'C013', 'C014', '0033', '0039', '009C', '002F', '0035', '00FF', 'C007', 'C011', '0005', 'C02C', 'C030', '009F', '009D']
# CCS values in common with training data: 12
# CCS values unique to this dataset: 8
# Unique CCS values: C011, C007, 0033, 0005, 009E, 009F, 00FF, 0039
# Processed dataset shape: (7122, 55) (7122 samples with 55 features)
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step
#
# RECONSTRUCTION ERROR ANALYSIS:
# Average reconstruction error: 0.966031
# Median reconstruction error:  0.121078
# Std deviation of errors:      13.845095
# Min reconstruction error:     0.001090
# Max reconstruction error:     534.117599
#
# ERROR DISTRIBUTION (PERCENTILES):
# 25th percentile: 0.093118
# 50th percentile: 0.121078
# 75th percentile: 0.393465
# 90th percentile: 0.839452
# 95th percentile: 1.228162
# 99th percentile: 3.627219
#
# WORST RECONSTRUCTED SAMPLES:
# Sample 5632: Reconstruction Error = 534.117599
# Sample 5909: Reconstruction Error = 475.946156
# Sample 3721: Reconstruction Error = 445.108163
# Sample 2489: Reconstruction Error = 441.342359
# Sample 5738: Reconstruction Error = 322.638844
# Sample 1242: Reconstruction Error = 303.292398
# Sample 104: Reconstruction Error = 197.524105
# Sample 3214: Reconstruction Error = 194.515255
# Sample 19: Reconstruction Error = 193.079638
# Sample 246: Reconstruction Error = 192.469607
#
# BEST RECONSTRUCTED SAMPLES:
# Sample 6732: Reconstruction Error = 0.001090
# Sample 6728: Reconstruction Error = 0.001108
# Sample 872: Reconstruction Error = 0.033410
# Sample 4627: Reconstruction Error = 0.033450
# Sample 3483: Reconstruction Error = 0.033526
# Sample 3147: Reconstruction Error = 0.033584
# Sample 1565: Reconstruction Error = 0.033606
# Sample 3118: Reconstruction Error = 0.033674
# Sample 5878: Reconstruction Error = 0.033911
# Sample 3176: Reconstruction Error = 0.034277
# PERFORMANCE SUMMARY:
# Dataset: cic-aa.adware TLS Dataset
# Number of samples: 7122
# Number of features: 55
# Average reconstruction error: 0.966031
# Processing time: 1.13 seconds
#
# ================================================================================
# COMPARISON OF DATASETS
# ================================================================================
#                    Dataset  Samples  Features  Avg Error     Max Error  Min Error
#           ISCX TLS Dataset     1112        55   0.299218     21.096177   0.001216
#         Mobile TLS Dataset     5616        55   0.022847      0.267810   0.000199
#        windows TLS Dataset    15047        55   0.002656      0.160804   0.000134
#  cic-aa.normal TLS Dataset    31179        55 448.125089 734905.139480   0.000838
# cic-aa.malware TLS Dataset      462        55   0.360867     23.866078   0.031746
#  cic-aa.adware TLS Dataset     7122        55   0.966031    534.117599   0.001090
#
# ================================================================================
# CCS USAGE COMPARISON BETWEEN DATASETS
# ================================================================================
# Total unique CCS values across all datasets: 36
# CCS values common to all datasets: 8
# Common CCS: C02B, C013, C02F, 002F, 0035, C009, C00A, C014
#
# CCS values unique to iscx: 6
# Unique CCS: 0004, 0032, 0038, 0045, 0088, 0016
#
# CCS values unique to mobile: 2
# Unique CCS: C008, C012
#
# CCS values unique to windows: 2
# Unique CCS: C027, C024
